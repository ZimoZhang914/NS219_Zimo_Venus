# %% [markdown]
# # 01 — Explore VINE-seq microglia
#
# Quick interactive look at the dataset before running the full pipeline.
# Run cells one-by-one to inspect loading, QC, and the VAE latent space.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent / 'src'))

import scanpy as sc
from microglia_annotator import load_config
from microglia_annotator import data as data_mod
from microglia_annotator import preprocessing as pp_mod

# %%
cfg = load_config('../configs/default.yaml')
cfg

# %%
adata = data_mod.load_anndata(cfg)
adata

# %%
adata.obs[cfg.data.celltype_col].value_counts()

# %%
adata = data_mod.subset_microglia(adata, cfg)
adata = data_mod.attach_condition(adata, cfg)
adata = pp_mod.quality_control(adata, cfg)
adata = pp_mod.normalize_and_hvg(adata, cfg)
adata = pp_mod.batch_correct(adata, cfg)
adata

# %%
# After this, run scripts/run_pipeline.py for the full VAE + classifier.
